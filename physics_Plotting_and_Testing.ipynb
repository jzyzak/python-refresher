# %%
import physics
import numpy as np

# %%
t_test, x_test, y_test, theta_test, v_test, omega_test, a_test = physics.simulate_auv2_motion(np.array([1, 0, 1, 0]), 0.5, 1.5, 1.8, dt=0.1, t_final=0.3)
physics.plot_auv2_motion(t_test, x_test, y_test, theta_test, v_test, omega_test, a_test)

# %%
t_test, x_test, y_test, theta_test, v_test, omega_test, a_test
# Out:
# (array([0. , 0.5, 1. ]),
#  array([0., 0., 0.]),
#  array([0., 0., 0.]),
#  array([0.        , 0.        , 0.01149393]),
#  array([[0., 0.],
#         [0., 0.],
#         [0., 0.]]),
#  array([0.        , 0.02298787, 0.04597574]),
#  array([[0., 0.],
#         [0., 0.],
#         [0., 0.]]))
