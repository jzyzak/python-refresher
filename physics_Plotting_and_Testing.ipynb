# %%
import physics
import numpy as np

# %%
t_test, x_test, y_test, theta_test, v_test, omega_test, a_test = physics.simulate_auv2_motion(np.array([1, 3, 1, 2]), 0.5, 1.5, 1.8)
physics.plot_auv2_motion(t_test, x_test, y_test, theta_test, v_test, omega_test, a_test)
